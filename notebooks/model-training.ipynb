# %%
# %load_ext kedro.ipython
# Out:
# [03/19/24 11:00:04] INFO     Registered line magic '%reload_kedro'                                   ]8;id=486133;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=870296;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#51\51]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=145831;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=754328;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#53\53]8;;\
#                     INFO     Resolved project path as: /Users/dani/dev/Work/AWS/kedros-tuts.        ]8;id=342183;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=370998;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#164\164]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/19/24 11:00:06] INFO     Kedro project spaceflights                                             ]8;id=120348;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=200335;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=863701;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=657512;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#135\135]8;;\
#                              'pipelines'
# [03/19/24 11:00:07] INFO     Registered line magic 'run_viz'                                        ]8;id=68492;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=215804;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#141\141]8;;\

# %%
# %reload_kedro
# Out:
# [03/19/24 12:59:31] INFO     Resolved project path as: /Users/dani/dev/Work/AWS/kedros-tuts.        ]8;id=124120;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=367535;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#164\164]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/19/24 12:59:33] INFO     Kedro project spaceflights                                             ]8;id=478911;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=614683;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=959368;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=109393;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#135\135]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=361061;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=683694;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#141\141]8;;\

# %%
catalog.load("params:a")
# Out:
# [03/19/24 12:59:55] INFO     Loading data from params:a (MemoryDataset)...                      ]8;id=475165;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=280592;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#483\483]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 1

# %%
df = catalog.load("model_input_table")
# Out:
# [03/19/24 11:06:13] INFO     Loading data from model_input_table (ParquetDataset)...            ]8;id=664532;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=915748;file:///Users/dani/dev/Work/AWS/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#483\483]8;;\

# %%
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     id_x       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 1  49438      Wallis and Futuna      Type V2      Plasma  ThetaBase Services
# 2  10750                   Niue      Type F5     Quantum  ThetaBase Services
# 3   4146                  Malta      Type V2     Quantum  ThetaBase Services
# 4   5067                  Malta      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      2.0                   4            moderate   2.0             False
# 1      3.0                   5            moderate   3.0             False
# 2      1.0                   2              strict   1.0              True
# 3      1.0                   2            moderate   1.0             False
# 4      5.0                  10              strict   5.0             False
#
#    ...  review_scores_crew  review_scores_location  review_scores_price  \
# 0  ...                 9.0                     9.0                  9.0
# 1  ...                10.0                    10.0                  9.0
# 2  ...                10.0                    10.0                 10.0
# 3  ...                10.0                     9.0                  9.0
# 4  ...                10.0                     9.0                 10.0
#
#    number_of_reviews  reviews_per_month   id_y  company_rating  \
# 0                 26               0.77  32413           100.0
# 1                 61               0.62  14122           100.0
# 2                467               4.66  47761           100.0
# 3                318               3.22  26648           100.0
# 4                 22               0.29  26648           100.0
#
#    company_location  total_fleet_count  iata_approved
# 0     Faroe Islands                1.0          False
# 1             Malta                1.0           True
# 2              Niue                2.0          False
# 3              Niue                2.0           True
# 4              Niue                2.0           True
#
# [5 rows x 28 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
features = [
  "engines", 
  "passenger_capacity",
  "crew",
  "d_check_complete",
  "moon_clearance_complete",
  "iata_approved",
  "company_rating",
  "review_scores_rating",
]

# %%
X = df[features]
y = df["price"]

# %%
import pandas as pd

# %%
def split_data(df: pd.DataFrame, parameters: dict) -> tuple: 
  X = df[parameters["features"]]
  y = df["price"]
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=parameters["test_size"])
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.3721129837539314
